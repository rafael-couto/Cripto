# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import *
from timedelta import *

# %%
cripto = """BTC-USD
ETH-USD
USDT-USD
BNB-USD
ADA-USD
DOGE-USD
XRP-USD
USDC-USD
DOT1-USD
UNI3-USD
ICP1-USD
BCH-USD
LTC-USD
LINK-USD
SOL1-USD
HEX-USD
MATIC-USD
THETA-USD
XLM-USD
VET-USD
ETC-USD
FIL-USD
TRX-USD
EOS-USD
XMR-USD
"""

# %%
today=date.today()
ult_180d = today + timedelta(days = -181)

# %%
daily_data = yf.download(cripto, start=ult_180d, end=today)
daily_data
# Out:
# [*********************100%***********************]  25 of 25 completed
#            Adj Close                                                  \
#              ADA-USD     BCH-USD     BNB-USD       BTC-USD  DOGE-USD
# Date
# 2020-12-08  0.140928  267.548462   27.636307  18321.144531  0.003179
# 2020-12-09  0.148165  268.709961   28.129305  18553.916016  0.003158
# 2020-12-10  0.141994  265.980682   27.696190  18264.992188  0.003105
# 2020-12-11  0.139449  259.331024   27.361004  18058.904297  0.003079
# 2020-12-12  0.144460  267.714569   28.164452  18803.656250  0.003163
# ...              ...         ...         ...           ...       ...
# 2021-06-02  1.752824  697.912964  401.262329  37575.179688  0.423374
# 2021-06-03  1.840471  718.448181  427.807922  39208.765625  0.399963
# 2021-06-04  1.710908  671.139160  391.395325  36894.406250  0.376323
# 2021-06-05  1.659009  649.438354  390.431854  35551.957031  0.372177
# ...

# %%
minute_data=yf.download(cripto, period='60d', interval='15m')
# Out:
# [*********************100%***********************]  25 of 25 completed

# %%
minute_data
# Out:
#                           Adj Close                                        \
#                             ADA-USD     BCH-USD     BNB-USD       BTC-USD
# Datetime
# 2021-04-10 00:00:00+01:00  1.200265  633.968933  440.468842  58082.640625
# 2021-04-10 00:15:00+01:00  1.202905  636.294067  445.402924  58161.070312
# 2021-04-10 00:30:00+01:00  1.204410  635.768372  448.227631  58189.601562
# 2021-04-10 00:45:00+01:00  1.203539  635.706726  453.178497  58245.003906
# 2021-04-10 01:00:00+01:00  1.203784  636.822449  459.471619  58384.953125
# ...                             ...         ...         ...           ...
# 2021-06-08 02:06:04+01:00       NaN         NaN         NaN           NaN
# 2021-06-08 02:06:05+01:00       NaN         NaN         NaN           NaN
# 2021-06-08 02:06:06+01:00       NaN         NaN         NaN           NaN
# 2021-06-08 02:06:07+01:00       NaN         NaN         NaN           NaN
# ...
